# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshanibiswal1111/python/blob/main/Untitled4_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ["priya", "sakshi", "riya", "punam", "diksha"]

for name in students:
  print(name)
# Out:
# priya
# sakshi
# riya
# punam
# diksha

# %%
numbers = [10, 20, 30, 40, 50]

print("first element: ", numbers[0])
print("last element: ", numbers[-1])
# Out:
# first element:  10
# last element:  50

# %%
fruits = ["apple", "banana", "cherry"]

fruits.append("strawberry")

print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'strawberry']

# %%
subjects = ["math", "odia", "english", "gk"]
subjects.insert(2, "AI")
print(subjects)
# Out:
# ['math', 'odia', 'AI', 'english', 'gk']

# %%
numbers = [1, 2, 3, 4, 5]
numbers.pop(2)
print(numbers)
# Out:
# [1, 2, 4, 5]

# %%
numbers = [10, 20, 30, 40, 50]

print("length of the list:", len(numbers))
print("maximum value:", max(numbers))
print("minimum value:", min(numbers))
print("sum of all element:", sum(numbers))
# Out:
# length of the list: 5
# maximum value: 50
# minimum value: 10
# sum of all element: 150

# %%
numbers = []
for i in range(5):
  num = int(input("enter a number"))
  numbers.append(num)
print("complete list:", numbers)
# Out:
# enter a number25
# enter a number20
# enter a number10
# enter a number65
# enter a number15
# complete list: [25, 20, 10, 65, 15]

# %%
cities = ["mumbai", "pune", "Delhi", "kolkata"]

if "Delhi" in cities:
  print("Delhi exists in the list.")
else:
  print("Delhi does not exists in the list.")
# Out:
# Delhi exists in the list.

# %%
colours = ("red", "green", "pink", "white", "black")

for colors in colours:
  print(colors)
# Out:
# red
# green
# pink
# white
# black

# %%
numbers = (10, 20, 30, 40, 50)

print("first element:", (numbers[0]))
print("last element:", (numbers[-1]))
# Out:
# first element: 10
# last element: 50

# %%
students = ("priya", "sakshi", "priya", "punam", "diksha")

print("priya, appears:", students.count("priya"), "times")
# Out:
# priya, appears: 2 times

# %%
numbers = (50, 60, 70, 80, 90)

print("maximum value:", max(numbers))
print("minimum value:", min(numbers))
print("length of tuple:", len(numbers))
# Out:
# maximum value: 90
# minimum value: 50
# length of tuple: 5

# %%
colors = ("red", "green", "pink")
colors[1] = "yellow"
print(colors)

# output: typeError: 'tuple' object does not support item assignment
# observation: Tuple is immutable.
# once a tuple is created, its values cannot be changed.

# %%
numbers = (1, 2, 3, 4, 5)
numbers_list = list(numbers)
print(numbers_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = {10, 20, 30, 40, 50}

print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
numbers = {10, 20, 30}
numbers.add(40)
print(numbers)
# Out:
# {40, 10, 20, 30}

# %%
numbers = {10, 20, 30, 40}
numbers.remove(20)
print(numbers)
# Out:
# {40, 10, 30}

# %%
numbers = {10, 20, 30, 40, 40}
print(numbers)

# set doesnot allow duplicate values.
# duplicate elements are automatically removed.
# Out:
# {40, 10, 20, 30}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("union:", A.union(B))
print("intersection:", A.intersection(B))
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}

# %%
numbers = {10, 20, 30, 40, 50}
num = int(input("enter a number: "))

if num in numbers:
  print("number is exists in the set")
else:
  print("number does not exists in the set")
# Out:
# enter a number: 30
# number is exists in the set

# %%
student = {
    "name": "priya",
    "age": 22,
    "city":  "mumbai"
}

print(student.values())
# Out:
# dict_values(['priya', 22, 'mumbai'])

# %%
student = {
    "name": "siva",
    "age": 24
}
student["course"] = "python"

print(student)
# Out:
# {'name': 'siva', 'age': 24, 'course': 'python'}

# %%
employee ={
    "id": 111,
    "name": "biswal",
    "salary": 100000

  }

print("keys:", employee.keys())
print("values:", employee.values())
# Out:
# keys: dict_keys(['id', 'name', 'salary'])
# values: dict_values([111, 'biswal', 100000])

# %%
student = {
    "name": "biswal",
    "age": 22

}

student["age"] = 23
print(student)
# Out:
# {'name': 'biswal', 'age': 23}

# %%
student = {
    "name": "test",
    "age": 24,
    "city": "chennai"
}
student.pop("city")
print(student)
# Out:
# {'name': 'test', 'age': 24}

# %%
students = {
    "priya": 90,
    "sona": 75,
    "soni": 94,
    "riya": 85,
    "rishi": 76
}
for name in students:
     print(name)
# Out:
# priya
# sona
# soni
# riya
# rishi

# %%
products = {
    "Laptop": 50000,
    "Mobile": 20000,
    "Mouse": 500
}

product = input("Enter product name: ")

if product in products:
    print("Price:", products[product])
else:
    print("Product not found")
# Out:
# Enter product name: Laptop
# Price: 50000

# %%
student = {
    "name": "Priya",
    "age": 24
}

key = input("Enter key: ")

if key in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Enter key: name
# Key exists

# %%
students = ["Priya", "Rahul", "Amit", "Soni", "Neha"]

student_tuple = tuple(students)

print(student_tuple)
# Out:
# ('Priya', 'Rahul', 'Amit', 'Soni', 'Neha')

# %%
students = {
    "Priya": 90,
    "Rahul": 75,
    "Amit": 85,
    "Soni": 70,
    "Neha": 95
}

for name, marks in students.items():
    if marks > 80:
        print(name, marks)
# Out:
# Priya 90
# Amit 85
# Neha 95
