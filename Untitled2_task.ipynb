# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshanibiswal1111/python/blob/main/Untitled2_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 student_name = input("enter student name: ")
print(student_name.upper())
# Out:
# PRIYADARSHANI

# %%
city_name = input("enter city name: ")
print(city_name)
print(city_name.upper())
print(city_name.lower())
print(city_name.title())
# Out:
# odisha
# ODISHA
# odisha
# Odisha

# %%
text_value = input("enter a string: ")
print("total length: ", len(text_value))
# Out:
# total length:  1

# %%
text_value = input("enter a string: ")
print("first character: ", text_value[0])
print("last character: ", text_value[-1])
# Out:
# enter a string: priya
# first character:  p
# last character:  a

# %%
name = input("enter a string: ")
print("number of 'a' letters: ", name.count('a'))
# Out:
# enter a string: biswal
# number of 'a' letters:  1

# %%
name = "python"
name2 = name.replace("python", "AI")
print("updated name:", name2)
# Out:
# updated name: AI

# %%
email_address = input("enter email address: ")
print(email_address.endswith("@gmail.com"))
# Out:
# enter email address: sopi@gmail.com
# True

# %%
user = input("enter")
print(user.isdigit())
# Out:
# enter12556
# True

# %%
user_input = input("enter something: ")
print(user_input.isalpha())
# Out:
# enter something: programming
# True

# %%
fruit_string = "apple, mango, banana, orange"
fruit_list = fruit_string.split (",")
print("list: ", fruit_list)
# Out:
# list:  ['apple', ' mango', ' banana', ' orange']

# %%
age = int(input("enter age: "))
if age >= 18:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# enter age: 25
# eligible to vote

# %%
number = int(input("enter a number: "))
if number > 0:
  print("positive")
elif number < 0:
  print("negative")
else:
  print("zero")
# Out:
# enter a number: 5
# positive

# %%
first_number = int(input("enter first number: "))
second_number = int(input("enter second number"))
if first_number > second_number:
  print("greater number: ", first_number)
else:
  print("greater number: ", second_number)
# Out:
# enter first number: 25
# enter second number52
# greater number:  52

# %%
marks = int(input("enter marks: "))
if marks >= 90 and marks <= 100:
  print("grade A")
elif marks >= 75 and marks <= 89:
  print("grade B")
elif marks >= 50 and marks <=74:
  print("grade C")
else:
  print("fail")
# Out:
# enter marks: 90
# grade A

# %%
number = int(input("enter a number: "))
if number % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# enter a number: 65
# odd

# %%
password = input("enter password")
if len(password) >= 8:
  print("strong password")
else:
  print("weak password")
# Out:
# enter passwordsopi2345
# strong password

# %%
year = int(input("enter a year"))
if (year % 4 == 0 and year % 100 !=0) or (year % 400 == 0):
  print("leap year")
else:
  print("not a leap year")
# Out:
# enter a year2026
# not a leap year

# %%
num1 = float(input("enter first number"))
num2 = float(input("enter second number"))
num3 = float(input("enter third number"))
if num1 >= num2 and num1 >= num3:
  largest_number = num1
elif num2 >= num1 and num2 >= num3:
  largest_number = num2
else:
  largest_number = num3
print("largest number:", largest_number)
# Out:
# enter first number52
# enter second number41
# enter third number32
# largest number: 52.0

# %%
username = input("enter username: ")
password = input("enter password: ")
if username == "admin" and password == "1234":
  print("login successful")
else:
  print("invalid credential")
# Out:
# enter username: admin
# enter password: 1234
# login successful

# %%
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))

operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", first_number + second_number)

elif operator == "-":
    print("Result:", first_number - second_number)

elif operator == "*":
    print("Result:", first_number * second_number)

elif operator == "/":
    print("Result:", first_number / second_number)

else:
    print("Invalid Operator")
# Out:
# Enter first number: 10
# Enter second number: 5
# Enter operator (+, -, *, /): *
# Result: 50.0
